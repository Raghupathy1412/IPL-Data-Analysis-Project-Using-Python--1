# %% [markdown]
# #                IPL DATA ANALYSIS

# %%
Problem Statement: Here I have considered the available data for each of the 
                   player sold in the IPL 2022 auction and that of the retained
                   players from each franchise

This data contains information like - matches played, runs, wickets, average, 
                                      strike rate, catches, runouts, stumps,etc

Based on these data points - I'll try to create the best playing 11 from the 
                             availabe dataset of players.
    

We can summarize our analysis in the following steps:
    
    1. Extraction and loading the data
    2. Cleaning the data and removing the noise
    3. Analyze the data on different parameters
    4. Visualizing the important statistical findings
    5. Making the best playing 11.

# %%
#Here we are importing the necessary libraries like NumPY, pandas, matplotlib and seaborn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the data

# %%
To import the dataset, we wo-ill use the pandas package from the python programming 
language. The other packages like matplotlib, seaborn and numpy will be useful for
computations and creating visual representations.

# %%
data = pd.read_csv("IPLData.csv")

# %%
#head() returns the first 5 rows of the dataset

data.head()
# Out:
#        Player Name       Team Nationality Player_Type  Capped  Matches_Played  \
# 0   Shikhar Dhawan     Punjab      Indian      Batter       1           192.0
# 1    Shreyas Iyer     Kolkata      Indian      Batter       1            87.0
# 2   Faf Du Plessis  Bangalore    Overseas      Batter       1           100.0
# 3   Manish Pandey     Lucknow      Indian      Batter       1           154.0
# 4  Shimron Hetmyer  Rajasthan    Overseas      Batter       1            31.0
#
#      Runs  Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 0  5783.0    34.63       126.60      4.0             16.5     8.25
# 1  2375.0    31.67       123.96      NaN              NaN      NaN
# 2  2935.0    34.94       131.09      NaN              NaN      NaN
# 3  3560.0    30.69       121.83      NaN              NaN      NaN
# 4   517.0    25.85       151.17      NaN              NaN      NaN
#
#    Bowling_Strike_Rate  Catches  Run_outs  Stumps
# ...

# %%
#describe function will return the necessary information like count, mean, std deviation,
#etc for the entire dataset

data.describe()
# Out:
#            Capped  Matches_Played         Runs     Average  Strike_Rate  \
# count  235.000000      215.000000   165.000000  161.000000   163.000000
# mean     0.838298       43.897674   840.575758   21.792391   121.009939
# std      0.561802       48.695302  1270.341831   11.664156    30.739189
# min      0.000000        1.000000     0.000000    0.000000     0.000000
# 25%      0.500000       11.500000    67.000000   13.800000   112.635000
# 50%      1.000000       25.000000   289.000000   22.410000   128.630000
# 75%      1.000000       56.000000   954.000000   29.300000   137.550000
# max      2.000000      220.000000  6283.000000   58.500000   190.240000
#
#           Wickets  Bowling_average     Economy  Bowling_Strike_Rate  \
# count  140.000000       135.000000  143.000000           119.000000
# mean    31.485714        32.907185    8.223182            24.686134
# std     36.872420        18.191441    1.223541            12.982049
# ...

# %%
#Here we can check the number of nll values using the isna(), sum() method

data.isna().sum()
# Out:
# Player Name              0
# Team                     0
# Nationality              0
# Player_Type              0
# Capped                   0
# Matches_Played          20
# Runs                    70
# Average                 74
# Strike_Rate             72
# Wickets                 95
# Bowling_average        100
# Economy                 92
# Bowling_Strike_Rate    116
# Catches                208
# Run_outs               208
# Stumps                 208
# dtype: int64

# %%
#the info method will return the information about the dataset like the non null
#objects, and the data type of the element in the data.

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player Name          235 non-null    object
#  1   Team                 235 non-null    object
#  2   Nationality          235 non-null    object
#  3   Player_Type          235 non-null    object
#  4   Capped               235 non-null    int64
#  5   Matches_Played       215 non-null    float64
#  6   Runs                 165 non-null    float64
#  7   Average              161 non-null    float64
#  8   Strike_Rate          163 non-null    float64
#  9   Wickets              140 non-null    float64
#  10  Bowling_average      135 non-null    float64
#  11  Economy              143 non-null    float64
#  12  Bowling_Strike_Rate  119 non-null    float64
#  13  Catches              27 non-null     float64
#  14  Run_outs             27 non-null     float64
# ...

# %% [markdown]
# # Cleaning the Data

# %%
In the above data, the players can be initially segregated based on following parameters
    1. Capped - Batters,, Bowlers, Allrounders, Wicket Keeper
    2. Uncapped - Batters, Bowlers, Allrounders, Wicket Keepers
The Uncapped players are playing the IPL for the first time or the relavant data 
isn't available therefore we have used their domestic T20 performances.

# %%
#segregating data - Capped Batters only
#I have kept the batiing parameters to restict the analysis for batter specific tendencies

batters = data.loc[(data["Player_Type"]=="Batter")]

batters_new = batters.loc[(batters["Capped"] == 1)]

Capped_Batters = batters_new[['Player Name',
                             'Team',
                             'Nationality',
                             'Matches_Played',
                             'Runs',
                             'Average',
                             'Strike_Rate']]

# %%
#the segregation of the batters based on the capped data gives us the batters
#that have a history of playing IPL matches.

Capped_Batters.head()
# Out:
#        Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0   Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 1    Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 2   Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 3   Manish Pandey     Lucknow      Indian           154.0  3560.0    30.69
# 4  Shimron Hetmyer  Rajasthan    Overseas            31.0   517.0    25.85
#
#    Strike_Rate
# 0       126.60
# 1       123.96
# 2       131.09
# 3       121.83
# 4       151.17

# %%
#segregating data - Capped Bowlers only
#I have kept the bowling parameters, since i will purely judge the bowlers on their bowling statistics.

bowlers = data.loc[(data["Player_Type"] == "Bowler ")]

bowlers_new = bowlers.loc[(bowlers["Capped"] == 1)]

Capped_Bowlers = bowlers_new[['Player Name',
                             'Team',
                             'Nationality',
                             'Matches_Played',
                             'Wickets',
                             'Bowling_average',
                             'Economy',
                             'Bowling_Strike_Rate']]

# %%
#Capped Bowlers
Capped_Bowlers.head()
# Out:
#         Player Name       Team Nationality  Matches_Played  Wickets  \
# 36   Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 37     Trent Boult   Rajasthan    Overseas            62.0     76.0
# 38  Mohammad Shami     Gujarat      Indian            77.0     79.0
# 39      T Natarajan  Hyderabad      Indian            24.0     20.0
# 40   Deepak Chahar     Chennai      Indian            63.0     59.0
#
#     Bowling_average  Economy  Bowling_Strike_Rate
# 36            20.53     8.21                15.00
# 37            26.09     8.40                18.64
# 38            30.41     8.63                21.14
# 39            34.40     8.24                25.05
# 40            29.19     7.80                22.44

# %%
#segregating data - Capped Keepers  only
#I have kept only keeping the relavant parameters for the keepers

Keepers = data.loc[(data["Player_Type"]=="Keeper")]

Keepers_new = Keepers.loc[(Keepers["Capped"] == 1)]

Capped_Keepers = Keepers_new[['Player Name',
                             'Team',
                             'Nationality',
                             'Matches_Played',
                             'Runs',
                             'Average',
                             'Strike_Rate',
                             'Catches',
                             'Run_outs',
                             'Stumps']]

# %%
#Capped Keepers

Capped_Keepers.head()
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0     31.3
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0     29.4
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0     28.5
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0     41.5
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0     25.8
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 105        130.9     53.0       0.0    14.0
# 106        127.5     58.0      12.0     2.0
# 107        136.3     19.0       1.0     2.0
# 108        142.2     18.0       1.0     4.0
# 109        129.7    123.0      14.0    32.0

# %%
#segregating data - Capped Allrounders  only
#I have kept only the batting and bowling parameters for the allrounders to analyze all round performance

Allrounders = data.loc[(data["Player_Type"]=="Allrounder")]

Allrounders_new = Allrounders.loc[(Allrounders["Capped"] == 1)]

Capped_Allrounders = Allrounders_new[['Player Name',
                             'Team',
                             'Nationality',
                             'Matches_Played',
                             'Runs',
                             'Average',
                             'Strike_Rate',
                             'Wickets',
                             'Bowling_average',
                             'Economy',
                             'Bowling_Strike_Rate']]

# %%
#Capped Allrounders

Capped_Allrounders.head()
# Out:
#               Player Name       Team Nationality  Matches_Played    Runs  \
# 127  Ravichandran Ashwin   Rajasthan      Indian           167.0   456.0
# 128          Pat Cummins     Kolkata    Overseas            37.0   316.0
# 129         Dwayne Bravo     Chennai    Overseas           151.0  1537.0
# 130          Nitish Rana     Kolkata      Indian            77.0  1820.0
# 131          Jason Holder    Lucknow    Overseas            26.0   189.0
#
#      Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 127    11.12       109.88    145.0            27.80     6.91
# 128    19.75       140.44     38.0            30.13     8.24
# 129    22.94       130.25    167.0            24.32     8.36
# 130    28.00       132.46      7.0            22.00     8.03
# 131    14.54       121.15     35.0            22.46     8.20
#
#      Bowling_Strike_Rate
# 127                24.12
# 128                21.95
# 129                17.44
# 130                16.43
# 131                16.43

# %%
#Cleaning the data by making the null or NAn values to 0.

Capped_Batters = Capped_Batters.fillna(0)
Capped_Bowlers = Capped_Bowlers.fillna(0)
Capped_Allrounders = Capped_Allrounders.fillna(0)
Capped_Keepers = Capped_Keepers.fillna(0)

# %%
#checking null values in the date

print(Capped_Batters.isna().sum())
print("")
print(Capped_Bowlers.isna().sum())
print("")
print(Capped_Allrounders.isna().sum())
print("")
print(Capped_Keepers.isna().sum())
print("")
# Out:
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# dtype: int64
#
# Player Name            0
# Team                   0
# Nationality            0
# Matches_Played         0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64
#
# Player Name            0
# Team                   0
# Nationality            0
# Matches_Played         0
# Runs                   0
# Average                0
# Strike_Rate            0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64
#
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# Catches           0
# Run_outs          0
# Stumps            0
# dtype: int64

# %% [markdown]
# # Initial Analysis

# %%
# In this section we will analyse data for baters, bowlers, keepers and allrounders

#Analyse the Batters Data
#Here we have narrowed our analysis to batters who have a batting average more then 32.0

top_batters = Capped_Batters.loc[(Capped_Batters["Average"] >=32.0)]

#sorting the data in descending order - with respect to each parameter

top_batters_average = top_batters.sort_values('Average',ascending=False)
top_batters_strike_rate = top_batters.sort_values('Strike_Rate',ascending=False)
top_batters_runs = top_batters.sort_values('Runs',ascending=False)
top_batters_matches = top_batters.sort_values('Matches_Played',ascending=False)

# %%
#the data of each of the batters in descending order of batting average

top_batters_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
#
#      Strike_Rate
# 212       136.38
# 231       132.13
# 19        139.97
# 207       131.27
# 208       129.95
# 2         131.09
# 0         126.60
# 26        136.51

# %%
#the batters data in the descending order of strike rate

top_batters_strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
#
#      Strike_Rate
# 19        139.97
# 26        136.51
# 212       136.38
# 231       132.13
# 207       131.27
# 2         131.09
# 208       129.95
# 0         126.60

# %%
#the runs scored data of the batters in descending order.

top_batters_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 212       136.38
# 2         131.09
# 26        136.51
# 207       131.27
# 231       132.13

# %%
#the batters matches played data in descending order.

top_batters_matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 2         131.09
# 212       136.38
# 26        136.51
# 207       131.27
# 231       132.13

# %%
From our analysis, if we rank from 0-10, the top three batters that will come while analysis each of the above data are:
        1. David Warner
        2. KL Rahul
        3. Virat Kolhi

# %%
#Analyzing the Bowlers Date
#Here we have narrowed our analysis based on the bowling average of the players to be less than 24.0


top_bowlers = Capped_Bowlers.loc[(Capped_Bowlers["Bowling_average"] <=24.0)]

#sorting the data in descending order - with respect to each parameter

top_bowlers_average = top_bowlers.sort_values('Bowling_average')
top_bowlers_strike_rate = top_bowlers.sort_values('Bowling_Strike_Rate')
top_bowlers_wickets = top_bowlers.sort_values('Wickets',ascending=False)
top_bowlers_matches = top_bowlers.sort_values('Matches_Played',ascending=False)
top_bowlers_economy = top_bowlers.sort_values('Economy')

# %%
#this dataframe contains the top bowling averages in ascending order.

top_bowlers_average
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
#
# ...

# %%
#This dataframe consists of the top bowlers strike rates in ascending order

top_bowlers_strike_rate
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
#
# ...

# %%
#This dataframe consists of the top bowlers economy rate in ascending order

top_bowlers_economy
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
#
# ...

# %%
#This dataframe consists of the top bowlers who takes most wickets in descending order

top_bowlers_wickets
# Out:
#              Player Name       Team Nationality  Matches_Played  Wickets  \
# 50     Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215       Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 36        Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 103  Nathan Coulter-Nile  Rajasthan    Overseas            38.0     48.0
# 214   Varun Chakravarthy    Kolkata      Indian            31.0     36.0
# 234        Anrich Nortje      Delhi    Overseas            24.0     34.0
# 210      Arshdeep Singh      Punjab      Indian            23.0     30.0
# 93          Lungi Ngidi      Delhi     Overseas            14.0     25.0
# 88        Alzarri Joseph    Gujarat    Overseas             3.0      6.0
# 83            Rasikh Dar    Kolkata      Indian             1.0      1.0
# 87           Sean Abbott  Hyderabad    Overseas             2.0      0.0
# 101         Kuldip Yadav  Rajasthan      Indian             1.0      0.0
#
# ...

# %%
From the above analysis, if we rank down the parameters from 1-10 the top bowling options are as follows
    1. Kagiso Rabada
    2. Jasprit Bumrah
    3. Yuzvendra Chahal
    4. Nathan Coulter_Nile

# %%
#analyzing the allrounder Data
#We have narrowed our analysis by furthr segregating the allrounders based on strike rate equal to or more than 140.0

top_allrounders = Capped_Allrounders.loc[(Capped_Allrounders["Strike_Rate"] >= 140.0)]

top_allrounders_average = top_allrounders.sort_values('Average',ascending=False)
top_allrounders_strike_rate = top_allrounders.sort_values('Strike_Rate',ascending=False)
top_allrounders_runs = top_allrounders.sort_values('Runs',ascending=False)
top_allrounders_matches = top_allrounders.sort_values('Matches_Played',ascending=False)
top_allrounders_bowling_average = top_allrounders.sort_values('Bowling_average')
top_allrounders_bowling_strike_rate = top_allrounders.sort_values('Bowling_Strike_Rate')
top_allrounders_wickets = top_allrounders.sort_values('Wickets',ascending=False)
top_allrounders_economy = top_allrounders.sort_values('Economy')

# %%
#This dataframe consists of players average in descending order for top allrounders

top_allrounders_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
#this dataframe consists of the strike rate of allrounders in descending order

top_allrounders_strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
#
# ...

# %%
#this dataframe consists of the runs of all allrounders in descending order

top_allrounders_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
#this dataframe consists of the matches of all allrounders in descending order

top_allrounders_matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
#this dataframe consists of the bowling average of all allrounders in descending order

top_allrounders_bowling_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
#
# ...

# %%
#this dataframe consists of the bowling strike rate of all allrounders in descending order

top_allrounders_bowling_strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
#
# ...

# %%
#this dataframe consists of the wickets of all allrounders in descending order

top_allrounders_wickets
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
#
# ...

# %%
#this dataframe consists of the economy of all allrounders in descending order#

top_allrounders_economy
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0    15.64
# 223        Moeen Ali    Chennai    Overseas            34.0   666.0    22.97
# 202       Aman Khan     Kolkata      Indian             5.0    40.0    13.30
# 165     Jofra Archer     Mumbai    Overseas            35.0   195.0    15.00
# 195   Mohammad Nabi     Kolkata    Overseas            17.0   180.0    15.00
# 128     Pat Cummins     Kolkata    Overseas            37.0   316.0    19.75
# 154       K Gowtham     Lucknow      Indian            24.0   186.0    14.31
# 218     Glen Maxwell  Bangalore    Overseas            97.0  2018.0    25.23
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0    29.98
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0    29.31
# 211    Hardik Pandya    Gujarat      Indian            92.0  1476.0    27.33
#
# ...

# %%
From the above analysis, we rank down the top allrounders from 1-10 on various parameters. the top most allrounder options are as follows
    1. Andre Russell
    2. sunil Narine
    3. Hardik Pandya
    4. Jofra Archer

# %%
#Analyzing the Keepers Data
#we have narrowed our analyss down to keepers averaging more than 25.0

top_keepers = Capped_Keepers.loc[(Capped_Keepers["Average"] >=25.0)]

#sorting the data in descending order - with respect to each parameter

top_Keepers_average = top_keepers.sort_values('Average', ascending=False)
top_Keepers_strike_rate = top_keepers.sort_values('Strike_Rate', ascending=False)
top_Keepers_runs = top_keepers.sort_values('Runs', ascending=False)
top_Keepers_matches = top_keepers.sort_values('Matches_Played', ascending=False)
top_Keepers_catches = top_keepers.sort_values('Catches', ascending=False)
top_Keepers_runouts = top_keepers.sort_values('Run_outs', ascending=False)
top_Keepers_stumps = top_keepers.sort_values('Stumps', ascending=False)

# %%
#this dataframe consists of the keepers average of all allrounders in descending order

top_Keepers_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 108       142.20     18.0       1.0     4.0
# ...

# %%
#this dataframe consists of the keepers strike rate of all allrounders in descending order

top_Keepers_strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 219       150.00     34.0       3.0     1.0
# ...

# %%
#this dataframe consists of the keepers runs of all allrounders in descending order

top_Keepers_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
#this dataframe consists of the keepers matches of all allrounders in descending order

top_Keepers_matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
#this dataframe consists of the keepers catches of all allrounders in descending order

top_Keepers_catches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
#this dataframe consists of the keepers runouts of all allrounders in descending order

top_Keepers_runouts
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
#this dataframe consists of the keepers stumps of all allrounders in descending order

top_Keepers_stumps
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
The top 3 keepers from the above analysis are 
    1. Ms Dhoni
    2. Rishab Pant
    3. Dinesh Karthik

# %% [markdown]
# # Visualization for Enahanced Analysis

# %%
Now the initial analysis that has been done on the segregated data. You can create a 
few visual representations of the same to get better analysis of the data.

# %%
#Visualization of Batters Data
#This plot shows each of the top Batters Strike rate

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Strike_Rate', data=top_batters)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Strike_Rate'>

# %%
#this plot shows the top batters who got more runs

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Runs', data=top_batters)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Runs'>

# %%
#this plot shows the top batsmans who got more average

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Average', data=top_batters)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Average'>

# %%
#this plot shows the top batsmans who got more matches played

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Matches_Played', data=top_batters)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Matches_Played'>

# %%
Visualization of Bowlers Data

# %%
#This plot shows the bowling average of each of the top bowlers

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Bowling_average', data=top_bowlers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Bowling_average'>

# %%
#Economy

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Economy', data=top_bowlers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Economy'>

# %%
#Most Wickets

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Wickets', data=top_bowlers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Wickets'>

# %%
#Most Matches Played

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Matches_Played', data=top_bowlers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Matches_Played'>

# %%
#Bowling Strike Rate

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Bowling_Strike_Rate', data=top_bowlers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Bowling_Strike_Rate'>

# %%
Visualization of Top Allrounders

# %%
# Most Runs of Allrounders

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Runs', data=top_allrounders)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Runs'>

# %%
# Best Batting Average of Allrounders

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Average', data=top_allrounders)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Average'>

# %%
# Best Batting Strike Rate of Allrounders

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Strike_Rate', data=top_allrounders)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Strike_Rate'>

# %%
#Most Matches Played in Allrounders

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Matches_Played', data=top_allrounders)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Matches_Played'>

# %%
#Most Wickets taken in Allrounders

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Wickets', data=top_allrounders)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Wickets'>

# %%
#Best Bowling average in Allrounders

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Bowling_average', data=top_allrounders)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Bowling_average'>

# %%
#Best Bowling Strike Rate in Allrounders

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Bowling_Strike_Rate', data=top_allrounders)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Bowling_Strike_Rate'>

# %%
#Best Economy in Allrounders

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Economy', data=top_allrounders)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Economy'>

# %%
Visualization of Keepers

# %%
#Most runs in Keepers

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Runs', data=top_keepers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Runs'>

# %%
#Most Batting Average in Keepers

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Average', data=top_keepers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Average'>

# %%
#Most Batting Strike Rate in Keepers

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Strike_Rate', data=top_keepers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Strike_Rate'>

# %%
#Most Matches Played in Keepers

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Matches_Played', data=top_keepers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Matches_Played'>

# %%
#Most Catches in Keepers

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Catches', data=top_keepers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Catches'>

# %%
#Most Stumps in Keepers

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Stumps', data=top_keepers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Stumps'>

# %%
#Most Runouts in Keepers

plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Run_outs', data=top_keepers)
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Run_outs'>

# %% [markdown]
# # Forming our best Playing 11

# %%
1. We will consider the number of players from each category that the T20 world cup
   winning team and the last year's ipl winning team played in their final mathces
    
2. The Australia playing 11 consists of # Batters, 3 Allrounders, 4 Bowlers with 
   1 spin option and 1 wicket Keeper

3. The CSK consists of 4 Batters, 3 Allrounders, 3 Bowlers and 1 Wicket Keeper

4. FOr our final analysis we will consider the ratio  of players in the best 11 as follows

    1. 3 Batters
    2. 3 Allrounders
    3. 1 Keeper
    4. 4 Bowlers with atleast 2 Spin Options

# %%
#Batters for the final 11 David Warner, KL Rahul and Virat Kolhi

top_batters.reset_index(drop=True)
matches_values = [top_batters.iloc[6]['Matches_Played'],top_batters.iloc[2]['Matches_Played'], top_batters.iloc[5]['Matches_Played']]
runs_values = [top_batters.iloc[6]['Runs'],top_batters.iloc[2]['Runs'], top_batters.iloc[5]['Runs']]
average_values = [top_batters.iloc[6]['Average'],top_batters.iloc[2]['Average'], top_batters.iloc[5]['Average']]
Strike_rate_values = [top_batters.iloc[6]['Strike_Rate'],top_batters.iloc[2]['Strike_Rate'], top_batters.iloc[5]['Strike_Rate']]
Labels = ['KL Rahul','David Warner', 'Virat Kolhi']

fig, axes = plt.subplots(2,2,figsize=(10,10))
axes[0][0].set_title("Matches Played")
axes[0][1].set_title("Runs in the IPL Career")
axes[1][0].set_title("Strike Rate")
axes[1][1].set_title("Average")
sns.barplot(x=Labels, y=matches_values, ax=axes[0][0])
sns.barplot(x=Labels, y=runs_values, ax=axes[0][1])
sns.barplot(x=Labels, y=Strike_rate_values, ax=axes[1][0])
sns.barplot(x=Labels, y=average_values, ax=axes[1][1])
# Out:
# <AxesSubplot:title={'center':'Average'}>

# %%
#Allrounders for the final 11 - Hardik Pandya, Andre Russell and Sunil Narine 

top_allrounders.reset_index(drop=True)
matches_values = [top_allrounders.iloc[5]['Matches_Played'],top_allrounders.iloc[9]['Matches_Played'], top_allrounders.iloc[6]['Matches_Played']]
runs_values = [top_allrounders.iloc[5]['Runs'],top_allrounders.iloc[9]['Runs'], top_allrounders.iloc[6]['Runs']]
average_values = [top_allrounders.iloc[5]['Average'],top_allrounders.iloc[9]['Average'], top_allrounders.iloc[6]['Average']]
Strike_rate_values = [top_allrounders.iloc[5]['Strike_Rate'],top_allrounders.iloc[9]['Strike_Rate'], top_allrounders.iloc[6]['Strike_Rate']]
bowling_strike_rate_values = [top_allrounders.iloc[5]['Bowling_Strike_Rate'],top_allrounders.iloc[9]['Bowling_Strike_Rate'], top_allrounders.iloc[6]['Bowling_Strike_Rate']]
bowling_average_values = [top_allrounders.iloc[5]['Bowling_average'],top_allrounders.iloc[9]['Bowling_average'], top_allrounders.iloc[6]['Bowling_average']]
wickets_values = [top_allrounders.iloc[5]['Wickets'],top_allrounders.iloc[9]['Wickets'], top_allrounders.iloc[6]['Wickets']]
economy_values = [top_allrounders.iloc[5]['Economy'],top_allrounders.iloc[9]['Economy'], top_allrounders.iloc[6]['Economy']]

Labels = ['Andre Russell','Sunil Narine', 'Hardik Pandya']

fig, axes = plt.subplots(4,2,figsize=(20,20))
axes[0][0].set_title("Matches Played")
axes[0][1].set_title("Runs in the IPL Career")
axes[1][0].set_title("Strike Rate")
axes[1][1].set_title("Average")
axes[2][0].set_title("Bowling Strike Rate")
axes[2][1].set_title("Bowling Average")
axes[3][0].set_title("Wickets")
axes[3][1].set_title("Economy")


sns.barplot(x=Labels, y=matches_values, ax=axes[0][0])
sns.barplot(x=Labels, y=runs_values, ax=axes[0][1])
sns.barplot(x=Labels, y=Strike_rate_values, ax=axes[1][0])
sns.barplot(x=Labels, y=average_values, ax=axes[1][1])
sns.barplot(x=Labels, y=bowling_strike_rate_values, ax=axes[2][0])
sns.barplot(x=Labels, y=bowling_average_values, ax=axes[2][1])
sns.barplot(x=Labels, y=wickets_values, ax=axes[3][0])
sns.barplot(x=Labels, y=economy_values, ax=axes[3][1])
# Out:
# <AxesSubplot:title={'center':'Economy'}>

# %%
#Wicket Keeper for the final 11 - MS DHONI

matches_values = [top_keepers.iloc[8]['Matches_Played'], top_keepers.iloc[8]['Runs']]
average_values = [top_keepers.iloc[8]['Average'], top_keepers.iloc[8]['Strike_Rate']]
keeping_values = [top_keepers.iloc[8]['Catches'], top_keepers.iloc[8]['Stumps'],top_keepers.iloc[8]['Run_outs']]

Label1 = ['Matches','Runs']
Label2 = ['Average','Strike_Rate']
Label3 = ['Catches','Stumps','Run_outs']

fig,axes = plt.subplots(1,3, figsize=(20,10))
axes[0].set_title("Matches and Runs")
axes[1].set_title("Average and Strike Rate")
axes[2].set_title("Keeping Stats")

sns.barplot(x=Label1, y=matches_values, ax=axes[0])
sns.barplot(x=Label2, y=average_values, ax=axes[1])
sns.barplot(x=Label3, y=keeping_values, ax=axes[2])
# Out:
# <AxesSubplot:title={'center':'Keeping Stats'}>

# %%
#Bowlers for the Final 11 - Jasprit Bumrah, Kagiso Rabada, Arshdeep Singh, Yuzi Chahal

top_bowlers.reset_index(drop=True)
matches_values = [top_bowlers.iloc[10]['Matches_Played'],top_bowlers.iloc[0]['Matches_Played'], top_bowlers.iloc[8]['Matches_Played'],top_bowlers.iloc[1]['Matches_Played']]
wickets_values = [top_bowlers.iloc[10]['Wickets'],top_bowlers.iloc[0]['Wickets'], top_bowlers.iloc[8]['Wickets'], top_bowlers.iloc[1]['Wickets']]
bowling_average_values = [top_bowlers.iloc[10]['Bowling_average'],top_bowlers.iloc[0]['Bowling_average'], top_bowlers.iloc[8]['Bowling_average'], top_bowlers.iloc[1]['Bowling_average']]
bowling_strike_rate_values = [top_bowlers.iloc[10]['Bowling_Strike_Rate'],top_bowlers.iloc[0]['Bowling_Strike_Rate'], top_bowlers.iloc[8]['Bowling_Strike_Rate'], top_bowlers.iloc[1]['Bowling_Strike_Rate']]
economy_values = [top_bowlers.iloc[10]['Economy'],top_bowlers.iloc[0]['Economy'], top_bowlers.iloc[8]['Economy'], top_bowlers.iloc[1]['Economy']]

Labels = ['Jasprit Bumrah','Kagiso Rabada', 'Arshdeep Singh','Yuzi Chahal']

fig, axes = plt.subplots(3,2,figsize=(15,15))
axes[0][0].set_title("Matches Played")
axes[0][1].set_title("Wickets")
axes[1][0].set_title("Bowling Average")
axes[1][1].set_title("Bowling Strike Rate")
axes[2][0].set_title("Economy")

sns.barplot(x=Labels, y=matches_values, ax=axes[0][0])
sns.barplot(x=Labels, y=wickets_values, ax=axes[0][1])
sns.barplot(x=Labels, y=bowling_average_values, ax=axes[1][0])
sns.barplot(x=Labels, y=bowling_strike_rate_values, ax=axes[1][1])
sns.barplot(x=Labels, y=economy_values, ax=axes[2][0])
# Out:
# <AxesSubplot:title={'center':'Economy'}>

# %% [markdown]
# # Best playing 11 for IPL

# %%
batter1 = top_batters.loc[(top_batters['Player Name'] == 'KL Rahul ')]
batter2 = top_batters.loc[(top_batters['Player Name'] == 'David Warner ')]
batter3 = top_batters.loc[(top_batters['Player Name'] == 'Virat Kohli')]

keeper = top_keepers.loc[(top_keepers['Player Name'] == 'MS Dhoni')]

allrounder1 = top_allrounders.loc[(top_allrounders['Player Name'] == 'Hardik Pandya')]
allrounder2 = top_allrounders.loc[(top_allrounders['Player Name'] == 'Andre Russell')]
allrounder3 = top_allrounders.loc[(top_allrounders['Player Name'] == 'Sunil Narine ')]

bowler1 = top_bowlers.loc[(top_bowlers['Player Name'] == 'Kagiso Rabada ')]
bowler2 = top_bowlers.loc[(top_bowlers['Player Name'] == 'Jasprit Bumrah')]
bowler3 = top_bowlers.loc[(top_bowlers['Player Name'] == 'Yuzvendra Chahal ')]
bowler4 = top_bowlers.loc[(top_bowlers['Player Name'] == 'Arshdeep Singh ')]

# %%
final = [batter1, batter2, batter3, keeper, allrounder1, allrounder2, allrounder3, bowler1, bowler2, bowler3, bowler4]
final_team = pd.concat(final)
final_team = final_team.drop(labels=['Matches_Played', 'Runs','Average','Strike_Rate','Wickets',
                                    'Bowling_average', 'Economy', 'Bowling_Strike_Rate',
                                    'Catches', 'Run_outs', 'Stumps'],axis=1)
final_team.reset_index(drop=True)
# Out:
#           Player Name       Team Nationality
# 0           KL Rahul     Lucknow      Indian
# 1       David Warner       Delhi    Overseas
# 2         Virat Kohli  Bangalore      Indian
# 3            MS Dhoni    Chennai      Indian
# 4       Hardik Pandya    Gujarat      Indian
# 5       Andre Russell    Kolkata    Overseas
# 6       Sunil Narine     Kolkata    Overseas
# 7      Kagiso Rabada      Punjab    Overseas
# 8      Jasprit Bumrah     Mumbai      Indian
# 9   Yuzvendra Chahal   Rajasthan      Indian
# 10    Arshdeep Singh      Punjab      Indian
